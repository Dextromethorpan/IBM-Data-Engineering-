# %% [markdown]
# **HTTP Request**

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
import requests

# %%
import os
from PIL import Image
from IPython.display import IFrame

# %%
url='http://web.dm.uba.ar/images/logo_clean_wide.png'
r=requests.get(url)

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
header=r.headers
print(r.headers)
# Out:
# {'Date': 'Fri, 16 Apr 2021 18:29:12 GMT', 'Server': 'Apache/2.4.25 (Debian)', 'Last-Modified': 'Fri, 08 Mar 2019 19:18:35 GMT', 'ETag': '"d1c-5839a16dc36fb"', 'Accept-Ranges': 'bytes', 'Content-Length': '3356', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'image/png'}

# %%
r.headers['Content-type']
# Out:
# 'image/png'

# %%
path=os.path.join(os.getcwd(),'image.png')
path
# Out:
# '/content/image.png'

# %%
with open(path,'wb') as f:
  f.write(r.content)

# %%
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=275x52 at 0x7FEA76A25ED0>

# %% [markdown]
# **GET HTTP Request**

# %%
url_get='http://httpbin.org/get'
payload={"name":"Joseph", "ID":"123"}
r=requests.get(url_get,payload)

# %%
r.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=123'

# %%
r.text
# Out:
# '{\n  "args": {\n    "ID": "123", \n    "name": "Joseph"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.23.0", \n    "X-Amzn-Trace-Id": "Root=1-6079e00e-65c5e4fc2cd4d1761f0fbaa2"\n  }, \n  "origin": "34.74.96.200", \n  "url": "http://httpbin.org/get?name=Joseph&ID=123"\n}\n'

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# **POST HTTP Request**

# %%
url_post='http://httpbin.org/post'

# %%
r_post=requests.post(url_post,payload)

# %%
r_post.url
# Out:
# 'http://httpbin.org/post'

# %%
r_post.request.body
# Out:
# 'name=Joseph&ID=123'

# %%
r_post.headers
# Out:
# {'Date': 'Fri, 16 Apr 2021 19:16:33 GMT', 'Content-Type': 'application/json', 'Content-Length': '498', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r_post.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '18',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-6079e291-2fba96384a814510335ea593'},
#  'json': None,
#  'origin': '34.74.96.200',
#  'url': 'http://httpbin.org/post'}
